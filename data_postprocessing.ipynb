# %% [markdown]
# # Filtering

# %%
import pandas as pd
import os

songs_df = pd.read_csv(os.path.join("data", "songs_v1.csv"))
print("Length before filtering: ", len(songs_df))
# Out:
# Length before filtering:  10854

# %% [markdown]
# 1. Drop duplicates:

# %%
songs_df = songs_df.drop_duplicates(subset=["title", "artist"])
print("Length after dropping duplicates: ", len(songs_df))
# Out:
# Length after dropping duplicates:  10804

# %% [markdown]
# 2. Filter non ukr artists and dublicates of the same artist:

# %%
ARTISTS_BLACKLIST = [
    "Poshlaya Molly", "Poshlaja Molli", "Сметана band", "Corn Wave", "Потап И Настя Каменских", 
    "Светлана Лобода", "Valentin Strykalo", "Верка Сердючка", "Lюk", "kavabanga Depo kolibri", 
    "Quest Pistols Show", "Какая Разница", "Green Grey", "jockii druce", "Миша Марвин", 
    "Оля Полякова", "Михаил Бублик", "Алёна Винницкая", "Наталья Могилевская",
    "Таисия Повалий", "Сергій Жадан Та Собаки В Космосі", "Poshlaya Molly",
    "Valentin Strykalo", "INGRET", "Svitlana Nianio", "Vasily Richter",
    "MARUV & Boosin", "Сусіди Стерплять", "The Feels", "Grandma's smuzi", 
    "Табула Раса", "Олег Кензов", "Potap & Nastya", "Виталий Чирва", "TELLY GRAVE",
    "Анастасия Приходько", "glichery", "AShamaluevMusic", "daKooka", "4Wheel", "KLIM", "CLONNEX", 
    "bris", "Pencil Legs", "Mykola Dmytrovych Leontovych", "Odyn v kanoe", 
    "Святослав Вакарчук", "DJ Jedy", "Марія Чайковська", "The Ukrainians", "Los Colorados", 
    "Тіна Кароль", "Ірина Білик", "national radio"
    ]

songs_df = songs_df[~songs_df["artist"].isin(ARTISTS_BLACKLIST)]
print("Length after removing blacklisted artists: ", len(songs_df))
# Out:
# Length after removing blacklisted artists:  5872

# %% [markdown]
# 3. Remove songs that have brackets in the title (probably remixes of the original songs) or are too long:

# %%
songs_df = songs_df[~songs_df["title"].str.contains("\(") | ~songs_df["title"].str.contains("\)")]
songs_df = songs_df[~songs_df["title"].str.contains("\[") | ~songs_df["title"].str.contains("\]")]
songs_df = songs_df[~songs_df["title"].str.contains("\|")]
songs_df = songs_df[~songs_df["title"].str.contains("\.")]
songs_df = songs_df[songs_df["title"].str.len() < 30]

print("Length after filtering based on song title: ", len(songs_df))
# Out:
# Length after filtering based on song title:  4417

# %% [markdown]
# 4. Filter non ukr artists based on the songs' tags:
#
# Note: don't include russian here as a considerable amount of ukr songs have a missleading russian tag

# %%
TAGS_BLACKLIST = ["finnish", "japanese"]
songs_df = songs_df[~songs_df["title_tags"].str.contains("|".join(TAGS_BLACKLIST))]
print("Length after filtering based on title tags: ", len(songs_df))
# Out:
# Length after filtering based on title tags:  4341

# %% [markdown]
# Save the filtered songs to a new *.csv file:

# %%
songs_df.to_csv(os.path.join("data", "songs_filtered_v1.csv"), index=False)

# %% [markdown]
# # Data summary after filtering

# %%
import pandas as pd
import os

filtered_songs_df = pd.read_csv(os.path.join("data", "songs_filtered_v1.csv"))

# %%
print("Number of ukr artists: ", len(filtered_songs_df["artist"].unique()))
# Out:
# Number of ukr artists:  62

# %%
songs_per_artist = filtered_songs_df["artist"].value_counts()

print(f"Total number of songs: {len(filtered_songs_df)}\n")
print(f"Number of songs per artist:\n{songs_per_artist.describe()}")
# Out:
# Total number of songs: 4341
#
# Number of songs per artist:
# count     62.000000
# mean      70.016129
# std       21.063909
# min       18.000000
# 25%       53.000000
# 50%       75.500000
# 75%       87.750000
# max      100.000000
# Name: artist, dtype: float64

# %% [markdown]
# Save the current blacklist version to a *.txt file":

# %%
with open(os.path.join("configs", "artists_blacklist_v1.txt"), "w", encoding="utf-8") as f:
    f.write("\n".join(ARTISTS_BLACKLIST))

# %% [markdown]
# # Concat with YT fetched results

# %%
import pandas as pd
import os

filtered_songs_df = pd.read_csv(os.path.join("data", "songs_filtered_v1.csv"))
len(filtered_songs_df)
# Out:
# 4341

# %%
audios_5_df = pd.read_csv(os.path.join("metadata", "yt_songs_5_2_pages_filtered.csv"))
audios_10_df = pd.read_csv(os.path.join("metadata", "yt_songs_10_2_pages_filtered.csv"))
audios_more_df = pd.read_csv(os.path.join("metadata", "yt_songs_more_sooongs_filtered.csv"))

audios_df = pd.concat([audios_5_df, audios_10_df, audios_more_df], ignore_index=True)

print("Total: ", len(audios_df))
print("No yt_url: ", len(audios_df[audios_df["yt_url"].isnull()]))
# Out:
# Total:  4068
# No yt_url:  602

# %%
merged_df = pd.merge(filtered_songs_df, audios_df, on=["title", "artist"], how="left")

print("Columns: ", merged_df.columns.values)
print("Total: ", len(merged_df))
print("No yt_url: ", len(merged_df[merged_df["yt_url"].isnull()]))
# Out:
# Columns:  ['title' 'artist' 'title_listeners_x' 'title_scrobbles_x' 'title_tags_x'
#  'title_duration_x' 'title_listeners_y' 'title_scrobbles_y' 'title_tags_y'
#  'title_duration_y' 'yt_title' 'yt_url' 'yt_duration' 'yt_views'
#  'audio_path']
# Total:  4341
# No yt_url:  886

# %%
merged_df[["title", "artist", "audio_path", "yt_title", "yt_url", "yt_duration", "yt_views"]]\
    .to_csv(os.path.join("data", "yt_songs_filtered_v1.csv"), index=False)

# %% [markdown]
# Updated summary after fetching the missing songs:

# %%
import pandas as pd
import os

filtered_songs_df = pd.read_csv(os.path.join("data", "yt_songs_filtered_v1.csv"))

print("Columns: ", filtered_songs_df.columns.values)
print("Total: ", len(filtered_songs_df))
print("No yt_url: ", len(filtered_songs_df[filtered_songs_df["audio_path"].isnull()]))
# Out:
# Columns:  ['title' 'artist' 'audio_path' 'yt_title' 'yt_url' 'yt_duration'
#  'yt_views']
# Total:  4341
# No yt_url:  60

# %% [markdown]
# # Exploring non unique audio_path

# %%
import pandas as pd
import os

filtered_songs_df = pd.read_csv(os.path.join("data", "yt_songs_filtered_v1.csv"))

len(filtered_songs_df["audio_path"].unique())
# Out:
# 3227

# %%
non_unique_paths = filtered_songs_df["audio_path"].value_counts()[filtered_songs_df["audio_path"].value_counts() > 1].index.tolist()
non_unique_paths
# Out:
# ['audio\\Нумер 482 - Добрий ранок Україно - (Офіційний кліп- 2015).mp3',
#  'audio\\Ігор Кайдаш - цього вартує кохання (official mood video).mp3',
#  'audio\\Димна Сумiш - Зламанi.mp3',
#  'audio\\Серцевий Напад - Субкультура.mp3',
#  'audio\\Нумер 482 - Важлива | Official Video.mp3',
#  'audio\\Крихітка Цахес - На Першому Місці.mp3',
#  "audio\\Її душі зів'ялі квіти.mp3",
#  'audio\\◾Плач Єремії ◾ Вона ◾.mp3',
#  'audio\\Лента За Лентою.mp3',
#  'audio\\Лінія Маннергейма – Де твоя лінія?.mp3',
#  'audio\\Холодне Сонце - Тінь Кохання (remastered HQ).mp3',
#  'audio\\Один в каное - Подобається, як ти ідеш.mp3',
#  'audio\\Воплі Відоплясова - ВЕСНА.mp3',
#  'audio\\Воплі Відоплясова - Були на селі.mp3',
#  'audio\\Катя Chilly - Я - молодая [HD 720p].mp3',
#  'audio\\Плач Єремії - Ти втретє цього літа зацвітеш.mp3',
#  'audio\\Sashakhuy.mp3',
#  'audio\\Ало-але.mp3',
#  'audio\\Zalyshai.mp3',
#  'audio\\Воплі Відоплясова - Сонячні дні [Official Video].mp3',
#  'audio\\The Unsleeping — PTAHA FRED (Official Video).mp3',
#  'audio\\Обійми Дощу - Мертве Дерево і Вітер.mp3',
#  'audio\\Самотні ночі.mp3',
#  'audio\\Жадан і Собаки – Автозак (Офіційне відео).mp3',
#  'audio\\Орест Лютий - А я не москаль (архів 2012 р.).mp3',
#  'audio\\Жадан і Собаки feat. Gogol Bordello – 5-а авеню (Офіційне відео).mp3',
#  'audio\\Factychno Vyhraut Vsikh.mp3',
#  'audio\\Крихітка Цахес - Ангела, як я.mp3',
#  'audio\\Kalush Orchestra - Stefania (Official Video Eurovision 2022).mp3',
#  'audio\\Воплі Відоплясова - День Народження.mp3',
#  'audio\\Пачка цигарок.mp3',
#  'audio\\Dazzle Dreams - Shock Your Mind (HD).mp3',
#  'audio\\Воплі Відоплясова - Танцi.mp3',
#  'audio\\Ми - хлопці з Бандерштадту.mp3',
#  'audio\\Воплі Відоплясова - Зоряна осінь.mp3',
#  'audio\\Крихітка Цахес - Вменеємен.mp3',
#  'audio\\Карпати програли в футбол.mp3',
#  'audio\\Кедь Ми Пришла Карта.mp3',
#  'audio\\Воплі Відоплясова — Музіка [Official Video].mp3',
#  'audio\\Воплі Відоплясова - Любов [Official Video].mp3',
#  'audio\\Там, Під Львівським Замком.mp3',
#  'audio\\Холодне Сонце - 06. Зникле у сні.mp3',
#  'audio\\Чубай Тарас - Із Янголом на Плечі     Chubai Taras - Angel on my Shoulder.mp3',
#  'audio\\Олександр Пономарьов "Сам собі країна" - Скрябін. Концерт пам\'яті.mp3',
#  'audio\\RENIE CARES - ЗАРАТУСТРА.mp3',
#  'audio\\Perkalaba -Свято Грибів і Форелів (Svjato Hrybiv i Foreliv).mp3',
#  'audio\\QARPA - Вогонь [Фактично Самі].mp3',
#  'audio\\Фактично Самі. Кириян..mp3',
#  'audio\\А ти просто кохай #ponomarevlivestudio (частина 14).mp3',
#  'audio\\Ми Йдем Вперед.mp3',
#  'audio\\Хто це тут.mp3',
#  'audio\\Їхали козаки.mp3',
#  'audio\\Холодне сонце - При заході.mp3',
#  'audio\\Воплі Відоплясова - Таємнi сфери (офіційне відео).mp3',
#  'audio\\Є-є.mp3',
#  'audio\\Обійми Дощу \u200e– Зимова Елегія ( 2009, Prog Metal, Ukraine ).mp3',
#  "audio\\Холодне Сонце - Твоє ім'я (HD).mp3",
#  'audio\\Холодне Сонце - 10. Крижана зірка.mp3',
#  "audio\\Сорок пачок 'Верховини'.mp3",
#  'audio\\Антитіла - Бери своє.mp3',
#  'audio\\Обійми Дощу - Зоренько моя.mp3',
#  'audio\\Обійми Дощу — Дорогою вічності (Lipky Live Sessions).mp3',
#  'audio\\Глибина.mp3',
#  'audio\\Наосліп.mp3',
#  'audio\\The Unsleeping — ПРИПУСТИМ (Official Video).mp3',
#  'audio\\Один в каное - Пішы.mp3',
#  'audio\\Холодне Сонце - 05. Колискова.mp3',
#  'audio\\Перкалаба - Голяк.mp3',
#  'audio\\PROBASS ∆ HARDI - ДОБРОГО ВЕЧОРА (WHERE ARE YOU FROM?).mp3',
#  'audio\\Стіна.mp3',
#  'audio\\KALUSH - Зорі.mp3',
#  'audio\\Я підійду.mp3',
#  'audio\\До побачення, кохання.mp3',
#  'audio\\Христина Соловій - Тримай (official video).mp3',
#  "audio\\Б'ютіфул Карпати.mp3",
#  'audio\\Go_A - SHUM - Ukraine 🇺🇦 Official Music Video - Eurovision 2021.mp3',
#  'audio\\Всі Джерела Відкриті.mp3',
#  "audio\\Друга Ріка - П'ю з твоїх долонь.mp3",
#  'audio\\Орест Лютий - Ідьот кацап по городу (архів).mp3',
#  'audio\\Intro.mp3',
#  'audio\\Нумер 482 / Трилер (HD).mp3',
#  'audio\\Димна Суміш - В країні ілюзій.mp3',
#  'audio\\Ми ходили, дили, дили.mp3',
#  'audio\\Орест Лютий - "З ЧОГО ПОЧИНАЛАСЬ МОСКОВІЯ".mp3',
#  'audio\\Косар обрієм.mp3',
#  'audio\\Klavdia Petrivna — Я тобі брехала.mp3',
#  'audio\\Крашен вечір.mp3',
#  'audio\\Приїдь до мене у Мостиска.mp3',
#  'audio\\Тартак — Стільникове Кохання.mp3',
#  'audio\\Холодне Сонце - І Архімед і Галілей.mp3',
#  'audio\\Орест Лютий - "А ЧЕМНИЙ ЛЕГІНЬ У САДУ".mp3',
#  'audio\\Klavdia Petrivna — Уже світає.mp3',
#  'audio\\Орест Лютий - Слава Україні.mp3',
#  'audio\\Тління.mp3',
#  'audio\\Dazzle Dreams - Мила (HD).mp3',
#  'audio\\Досить!.mp3',
#  'audio\\МАША КОНДРАТЕНКО & MASHUKOVSKY - ВЕДМЕДІ-БАЛАЛАЙКИ (OFFICIAL VIDEO 2022).mp3',
#  'audio\\МАША КОНДРАТЕНКО - ВАНЬКА-ВСТАНЬКА (OFFICIAL VIDEO 2022).mp3',
#  'audio\\Воплi Вiдоплясова - Юра.mp3',
#  'audio\\Numer 482- Ні.mp3',
#  'audio\\Друга Ріка - Денніч.mp3',
#  'audio\\alyona alyona & Jerry Heil - Teresa & Maria (LIVE) | Ukraine 🇺🇦 | Grand Final | Eurovision 2024.mp3',
#  'audio\\Друга Ріка - Три хвилини.mp3',
#  'audio\\Орест Лютий   УКРАЇНО.mp3',
#  'audio\\Dazzle Dreams - Ікона (HD).mp3',
#  'audio\\Я люблю тільки тебе - Олександр Пономарьов.mp3',
#  'audio\\Нумер 482 - Вампір ● НАЖИВО.mp3',
#  'audio\\Р`Н`Р.mp3',
#  'audio\\Олександр Пономарьов - Ніченькою [Official Video].mp3',
#  'audio\\Жити знову.mp3',
#  'audio\\Брати Гадюкіни  - Ой лихо! (Chervona Ruta Festival 1989).mp3',
#  'audio\\Майстер з міста Hameln.mp3',
#  'audio\\Брати Гадюкіни. На долині туман шейк.mp3',
#  'audio\\Слова песни Нумер 482 - Файно - Звичайно.mp3',
#  'audio\\Катя Chilly. Цвіте рожа.mp3',
#  'audio\\Катя Chilly - Pivni (2005).mp3',
#  'audio\\Katya Chilly "Свєтліца" - выбор вслепую - Голос страны 7 сезон.mp3',
#  'audio\\Артем Пивоваров - Дежавю (UA Version).mp3',
#  'audio\\Один в каное - Дощі.mp3',
#  'audio\\PROBASS ∆ HARDI - САМ ГУЛЯЮ!.mp3',
#  'audio\\Серце.mp3',
#  'audio\\Тарас Чубай "Миколай Бородатий" (фрагмент фільму "На Різдво до Львівського").mp3',
#  'audio\\Katya Chilly - Півні / Pivni (2004).mp3',
#  'audio\\Водограй.mp3',
#  'audio\\Воплі Відоплясова - Країна Мрій.mp3',
#  'audio\\Буде Нам З Тобою Що Згадати....mp3',
#  'audio\\Катя Chilly - Красно-ясно.mp3',
#  'audio\\Vivienne Mort - Твоя.mp3',
#  'audio\\Тартак feat. Катя Chilly — Понад Хмарами....mp3',
#  'audio\\PROBASS ∆ HARDI - POLONYNA (Official video).mp3',
#  'audio\\Друга Ріка - Ти зі мною? Я здаюсь! [Official Music Video].mp3',
#  'audio\\Я твоє крило.mp3',
#  'audio\\Вставай, країно рідная!    народна творчість на мотив пісні Ореста Лютого.mp3',
#  'audio\\To Eternity - Несмачний мед (Official Lyric Video).mp3',
#  'audio\\Vivienne Mort — Думаю про тебе [офіційне відео].mp3',
#  "audio\\Klavdia Petrivna — Пам'ятай (техно).mp3",
#  'audio\\Klavdia Petrivna — Зима (OST «Потяг у 31 грудня»).mp3',
#  'audio\\Tember Blanche - про Київ.mp3',
#  'audio\\Tember Blanche  - Я вдома.mp3',
#  'audio\\Ми Хлопці з Бандерштату. Кому Вниз.mp3',
#  'audio\\Серцевий Напад - Go Fuck Yourself.mp3',
#  'audio\\Vivienne Mort — Хто ти такий? [Rosa, 2016].mp3',
#  'audio\\Христина Соловій - Хто, як не ти? (official video).mp3',
#  'audio\\Один в каное - Пообіцяй мені.mp3',
#  'audio\\Кому Вниз - Птаха на ймення Nachtigall.mp3',
#  'audio\\The Unsleeping - Fantastic (Official Video).mp3',
#  'audio\\Кому Вниз - Ліра (Украина).mp3',
#  'audio\\Нестримна течія.mp3',
#  'audio\\Серцевий напад. Інфаркт міокарда. Симптоми | Слухаємо лікаря.mp3',
#  'audio\\Христина Соловій - Сідит пташок (official audio).mp3',
#  'audio\\alyona alyona - Велика й смішна.mp3',
#  'audio\\Перкалаба - Гулєй.mp3',
#  'audio\\Якби Ти Знав.mp3',
#  'audio\\Жадан і Собаки, Христина Соловій – Серце (Офіційне відео).mp3',
#  'audio\\Бумбокс - Поліна (Full HD).mp3',
#  'audio\\Mad Heads XL - Зірки знають (official music video).mp3',
#  'audio\\Па Па.mp3',
#  'audio\\Ya Na Mori (Original Mix).mp3',
#  'audio\\Mad Heads XL - Пробки.mp3',
#  'audio\\Outro.mp3',
#  'audio\\Воплі Відоплясова - Світ.mp3',
#  'audio\\Ницо Потворно - Хто я.mp3',
#  'audio\\Ницо Потворно — Вибач Наташа.mp3',
#  'audio\\Ницо Потворно — Ти.mp3',
#  'audio\\Галю приходь - Воплі Відоплясова. 30 років.mp3',
#  'audio\\renie cares, polina maiboroda - дюшеска.mp3',
#  'audio\\Ницо Потворно — Єбучий фʼюча.mp3',
#  'audio\\АНТИТІЛА - НЕВИДИМКА (Official HD Ukrainian vers).mp3',
#  'audio\\Обійми Дощу - Згасаюча осінь (feat. Юрій Русланов).mp3',
#  'audio\\Жадан і Собаки – Марат  (Live Drum Session).mp3',
#  'audio\\Mad Heads XL - Screenка (official music video).mp3',
#  'audio\\Обійми Дощу - Світанок (відеокліп).mp3',
#  'audio\\QARPA - В Твоїх Обіймах [Фактично Самі].mp3',
#  'audio\\Ya vse skazav+.mp3',
#  'audio\\Гей, любо!.mp3',
#  'audio\\Жадан і Собаки – Мальви (Офіційне відео).mp3',
#  'audio\\Go-A - ЖАЛЬМЕНІНА [ZHALMENINA] (Audio).mp3',
#  "audio\\Вродливе м'ясо (feat. ФАКТИЧНО САМІ).mp3",
#  'audio\\Підманула.mp3',
#  'audio\\Перкалаба - Тікобивиходили / Perkalaba - Tikobyvyxodyly.mp3',
#  'audio\\Жадан і Собаки – Кобзон (Офіційне відео).mp3',
#  'audio\\Dazzle Dreams - S.O.S.mp3',
#  'audio\\Жадан і Собаки – Тьолка барабанщика (Офіційне відео).mp3',
#  'audio\\Бумбокс - Та4то | Official Video.mp3',
#  'audio\\Хоттабыч.mp3',
#  'audio\\Відрада.mp3',
#  'audio\\Фактично Самі - Пиздець Ко..ну.mp3',
#  'audio\\RENIE CARES - ЯКБИ.mp3',
#  'audio\\Бумбокс - Квіти в волоссі.wmv.mp3',
#  'audio\\Я і ти.mp3',
#  'audio\\Ты ушёл.mp3',
#  'audio\\Ницо Потворно — Моя слина на тобі feat. Саша Гонтар.mp3',
#  'audio\\Вона сама сюди прийшла.mp3',
#  'audio\\Гармонія.mp3',
#  'audio\\Воплі Відоплясова - Горіла Сосна.mp3',
#  'audio\\Антидепресанти.mp3',
#  'audio\\KAZKA — ТАНЦІ [OFFICIAL AUDIO].mp3',
#  'audio\\Вінні-Пух.mp3',
#  'audio\\Zlata Ognevich - Gravity (Ukraine) - LIVE - 2013 Grand Final.mp3',
#  'audio\\KAZKA — ВІН [OFFICIAL AUDIO].mp3',
#  'audio\\Char Dash (Original Mix).mp3',
#  'audio\\Трава.mp3',
#  'audio\\Perkalaba - Любові Поклик АУ-УА (Ljubovi Poklyk Au-Ua).mp3',
#  'audio\\Жадан і Собаки – Рок-музикант (Офіційне відео).mp3',
#  'audio\\Брати Гадюкіни - Файне місто Тернопіль.mp3',
#  'audio\\Пілігрим.mp3',
#  'audio\\Ближче.mp3',
#  'audio\\Нумер 482  -  Важлива.mp3',
#  'audio\\Patsani buri.mp3',
#  'audio\\Нумер 482 - Радіо твоє.mp3',
#  'audio\\#02. КОМУ ВНИЗ - Попіл. "Ретроспектива" у Львівській Опері, 2006.12.01.mp3',
#  'audio\\Чи знаєш ти?.mp3',
#  'audio\\Вона.mp3',
#  'audio\\KALUSH - Вайб.mp3',
#  'audio\\КОМУ ВНИЗ - Суботів.mp3',
#  'audio\\Маншигвери.mp3',
#  'audio\\Мені заборонили.mp3',
#  'audio\\Хочу почути.mp3',
#  'audio\\Мʼясо-фестиваль.mp3',
#  "audio\\Пароль до ї' губ.mp3",
#  'audio\\Забудь мене.mp3',
#  'audio\\О, панно Інно.mp3',
#  'audio\\Микита Швачка.mp3',
#  'audio\\Гей на горі, на Маківці.mp3',
#  'audio\\Крейсер Аврора - Крихитка Цахес.mp3',
#  'audio\\Давай займемось спортом.mp3',
#  'audio\\Розрита могила.mp3',
#  'audio\\структура щастя - птица говорун - speed up.mp3',
#  'audio\\Трохи про нас.mp3',
#  'audio\\Чуєш, мила.mp3',
#  'audio\\KAZKA — Плакала [Official Video].mp3',
#  'audio\\Прима.mp3',
#  'audio\\Приватна територія.mp3',
#  'audio\\KALUSH - Мала в 19.mp3',
#  "audio\\Нумер 482 - Свобода - Lyriсs video (Прем'єра 2015).mp3",
#  'audio\\KALUSH - Тіпок.mp3',
#  'audio\\Заповіт Арійській Людині.mp3',
#  'audio\\Щодня вона йде назустріч.mp3',
#  'audio\\KALUSH ft. Христина Соловій - Таксі.mp3',
#  'audio\\Ти зі мною.mp3',
#  'audio\\Крихітка Цахес - Деталь.mp3',
#  'audio\\Паперове кохання.mp3',
#  'audio\\Пароль.mp3',
#  'audio\\Слова песни Нумер 482 - Не Мовчи.mp3',
#  'audio\\KALUSH - Не маринуй.mp3',
#  'audio\\Майже Щаслива.mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - ДІМ (feat. drimandr).mp3',
#  "audio\\До Основ'яненка.mp3",
#  'audio\\KALUSH - Не забуду.mp3',
#  'audio\\Слова песни Нумер 482 - Тікаю Від Тебе.mp3',
#  'audio\\Скоро Буду Поруч.mp3',
#  'audio\\KALUSH - Ти гониш.mp3',
#  'audio\\Numer 482- Стрибай.flv.mp3',
#  "audio\\Нумер 482 - Коли вона поруч - Lyriсs video (Прем'єра 2017).mp3",
#  'audio\\Кому Вниз - Срібні твої води.mp3',
#  'audio\\Mosti.mp3',
#  'audio\\Numer 482 In London (Live) - Коли Вона Поруч.mp3',
#  'audio\\Нумер 482 - Космічні Квіти кавер (Am F C G).mp3',
#  'audio\\Ой, Марічко чичери.mp3',
#  'audio\\Blindfold.mp3',
#  'audio\\#10. КОМУ ВНИЗ - Не нарікаю я на Бога. "Ретроспектива" у Львівській Опері, 2006.12.01.mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - МОР.mp3',
#  'audio\\Катя Chilly - Вишенька.mp3',
#  'audio\\СУМ І ГНІВ.mp3',
#  'audio\\Жадан і Собаки – Метро (Аудіо).mp3',
#  'audio\\Брати Гадюкіни - Емігрант сонг (Emigrant song).mp3',
#  'audio\\Перекличка.mp3',
#  'audio\\Віскі.mp3',
#  'audio\\Жадан і Собаки – Діти (Повна версія) | Анімаційне відео.mp3',
#  'audio\\Брати Гадюкіни   Дупа Джалізовая   Live in Kyiv XX II MMVI.mp3',
#  'audio\\To Eternity - Несмачний мед (Official Video).mp3',
#  'audio\\Жадан і Собаки – Дивні люди (Офіційне відео).mp3',
#  'audio\\Печінка.mp3',
#  'audio\\Пісня про квартірний вопрос.mp3',
#  'audio\\Буратіно.mp3',
#  'audio\\Брати Гадюкіни - Чічка-Марічка.mp3',
#  'audio\\Вова.mp3',
#  'audio\\The Unsleeping - Жити (Official Lyric Video).mp3',
#  'audio\\The Unsleeping – DEDVED.mp3',
#  'audio\\Закладчик.mp3',
#  'audio\\Забухав.mp3',
#  'audio\\Крихітка. Ти щось неймовірне (Щось на зразок).mp3',
#  'audio\\Nadya.mp3',
#  'audio\\Брати Гадюкіни — 117 стаття Брати Гадюкіни Live in Kyiv XX II MMVI.mp3',
#  'audio\\Loreley.mp3',
#  'audio\\Жадан і Собаки - 300 китайців. #Селекція. Музична премія Джем ФМ.mp3',
#  'audio\\Брати Гадюкіни   Міську вважай    Live in Kyiv XX II MMVI.mp3',
#  'audio\\Арівідерчі, Рома.mp3',
#  'audio\\Disko Killers.mp3',
#  'audio\\Dazzle Dreams - Dana She Dana (HD).mp3',
#  'audio\\Dazzle Dreams -  Indigo.mp3',
#  'audio\\Dazzle Dreams - Emotional Lady (HD).mp3',
#  'audio\\Нумер 482 - Інтуіція / ELLO UP^ /.mp3',
#  'audio\\Рок-н-рол до рана.mp3',
#  'audio\\Я вернувся домів.mp3',
#  'audio\\Брати Гадюкіни Всьо Чотко 2011 OFFICIAL MUSIC VIDEO.mp3',
#  'audio\\Air Of Intro.mp3',
#  'audio\\The Unsleeping - Не Сплю (Official video).mp3',
#  'audio\\Жадан і Собаки – Виживи feat. Ірена Карпа (Офіційне відео).mp3',
#  "audio\\Tell Me What's Wrong.mp3",
#  'audio\\"Крихітка Цахес на прізвисько Цинобер" скорочено аудіокнига.  Ернст Гофман.mp3',
#  'audio\\Катя Chilly - Тебе нема.mp3',
#  'audio\\Жадан і Собаки – Мадонна (Lyric Video).mp3',
#  'audio\\Жадан і Собаки – Ріка (Офіційне відео).mp3',
#  'audio\\Жадан i Собаки – Троєщина (live @On-Air).mp3',
#  'audio\\Марія Бурмака Не забувається любов.mp3',
#  'audio\\Марія Бурмака Під облачком.mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - Сидативи.mp3',
#  'audio\\The Unsleeping - Переживу (Official Video).mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - ДРУГ.mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - Запам‘ятай мої рядки (feat. Sad Novelist).mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - СМУГА.mp3',
#  'audio\\Колискова.mp3',
#  'audio\\SadSvit - Силуети (feat. СТРУКТУРА ЩАСТЯ) Lyric video.mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - ДТП.mp3',
#  'audio\\Жадан і Собаки – Бухло (Офіційне відео).mp3',
#  'audio\\Катя Chilly - Син.mp3',
#  'audio\\Любов моя.mp3',
#  'audio\\Натаха.mp3',
#  'audio\\Katya Chilly - Zozulya.mp3',
#  'audio\\Катя Chilly - Русалки in da house (1998).mp3',
#  "audio\\АРТЕМ ПИВОВАРОВ - МІРАЖ [UA Version] (Прем'єра кліпа 2021).mp3",
#  'audio\\Жадан і Собаки feat. Брати Гадюкіни – Наркомани на городі (Жадан і Собаки cover).mp3',
#  'audio\\Жадан і Собаки – Кокаїн (Lyric Video).mp3',
#  'audio\\Ти - місяць.mp3',
#  'audio\\Артем Пивоваров - Ой На Горі.mp3',
#  'audio\\Катя Chilly - Івашечку.mp3',
#  'audio\\Жадан і Собаки –\xa0Вафлі Артек (Офіційне відео).mp3',
#  'audio\\Жадан і Собаки – Рогань (Офіційне відео).mp3',
#  'audio\\Katya Chilly - Pivni [Instrumental].mp3',
#  'audio\\Радіопромінь.mp3',
#  'audio\\To Eternity - Осінь (Official Lyric Video).mp3',
#  'audio\\Димна Суміш - Кожної весни.mp3',
#  'audio\\Океан Ельзи - Без бою | Bez boyu (official video).mp3',
#  'audio\\Нумер 482 - Не напишу.mp3',
#  'audio\\Mad Heads - А я на морі (official music video).mp3',
#  'audio\\Міста.mp3',
#  'audio\\Їй 15.mp3',
#  'audio\\Лінія Маннергейма – Чорний.mp3',
#  'audio\\Лінія Маннергейма – Ісус із Назарета.mp3',
#  'audio\\Zlata Ognevich - GRAVITY (remix - club edit).mp3',
#  'audio\\Обійми Дощу — Діти (Official Video).mp3',
#  'audio\\Обійми Дощу - Новий Початок [Audio].mp3',
#  'audio\\ZLATA OGNEVICH - Далеко.mp3',
#  'audio\\ZLATA OGNEVICH - DOLONI.mp3',
#  'audio\\Обійми Дощу - Під Хмарами.mp3',
#  'audio\\Mad Heads - Надія Є (official music video).mp3',
#  'audio\\Mad Heads - Буває (official music video).mp3',
#  'audio\\MAD HEADS XL - голівуд.mp3',
#  'audio\\Mad Heads - Пісня світла (official music video).mp3',
#  'audio\\Mad Heads XL - Найкраща мить (official music video).mp3',
#  'audio\\Mad Heads XL - Автобус буратін (official music video).mp3',
#  'audio\\Mad Heads XL - Добре (official music video).mp3',
#  'audio\\Mad Heads XL - Дощ.mp3',
#  'audio\\Mad Heads XL - Шлях До Неба.mp3',
#  'audio\\Mad Heads "Gangster\'s days".mp3',
#  'audio\\Mad Heads XL - Зброя і квіти.mp3',
#  'audio\\renie cares - навчи мене (music video).mp3',
#  'audio\\renie cares - моя весна (music video).mp3',
#  'audio\\Фактично Самі - Жінка-сокира Рубає.mp3',
#  'audio\\ZLATA OGNEVICH - Мій Назавжди.mp3',
#  'audio\\Вона Танцює.mp3',
#  'audio\\Південно-Західна.mp3',
#  'audio\\ZLATA OGNEVICH - Кукушка.mp3',
#  'audio\\Маша Кондратенко - жінки з сумними очима (Skit).mp3',
#  'audio\\Маша Кондратенко - хто це така? (OFFICIAL VIDEO 2024).mp3',
#  'audio\\МАША КОНДРАТЕНКО - люлі-люлі (OFFICIAL VIDEO 2023).mp3',
#  'audio\\МАША КОНДРАТЕНКО - вогник вогник.mp3',
#  'audio\\Маша Кондратенко — un deux trois [mood video].mp3',
#  'audio\\Маша Кондратенко - No Time to Cry (Eurovision Ukraine Vidbir 2025).mp3',
#  'audio\\Перкалаба - Бугай.mp3',
#  'audio\\Перкалаба - Горрри!.mp3',
#  'audio\\Перкалаба - Льотчик / Perkalaba - The Pilot.mp3',
#  'audio\\Perkalaba - Миєбітлс (Myjebitls).mp3',
#  'audio\\PERKALABA - PRERIJI/ПЕРКАЛАБА - ПРЕРІЇ.mp3',
#  'audio\\Perkalaba - Gorrry!.mp3',
#  "audio\\П'ята Ахілла.mp3",
#  'audio\\Перкалаба- Просерамерa.mp3',
#  'audio\\Перкалаба - Пісюни.mp3',
#  'audio\\Листя жовтня.mp3',
#  'audio\\Didograje.mp3',
#  'audio\\Арсен Мірзоян - Скажи чому [Official Video].mp3',
#  'audio\\За#Бали (feat. Юрій Гуржи).mp3',
#  'audio\\Арсен Мірзоян - Можеш як.mp3',
#  'audio\\Поцілуй.mp3',
#  'audio\\Жадан і Собаки – Бийся за неї (Live) | Архіви.mp3',
#  'audio\\ZLATA OGNEVICH - За лісами горами.mp3',
#  'audio\\Фактично самі | 2000-ні початок, рок-андеграунд, фрагмент | Рок-антологія.mp3',
#  'audio\\Фактично Самі - Дивом Дивуюсь.mp3',
#  'audio\\Димна Суміш - Танцюй Танцюй.mp3',
#  'audio\\Blooms Corda // Тетріси із фраз (Official video).mp3',
#  'audio\\Пікардійська терція - Богдан (Pikkardyjska Tercja - Bohdan)  A capella.mp3',
#  'audio\\Єбучі бабські справи.mp3',
#  'audio\\Ницо Потворно — Йайа звик | А може це я? (EP).mp3',
#  'audio\\Ницо Потворно — русні пізда.mp3',
#  'audio\\Хуйня рухома.mp3',
#  'audio\\Цікаве життя.mp3',
#  'audio\\Окситоцин.mp3',
#  'audio\\Serce Moe.mp3',
#  'audio\\Scho Take Bez-Tebe-Vechir.mp3',
#  'audio\\Трамвай.mp3',
#  'audio\\Viter.mp3',
#  'audio\\Soldat Na Placu.mp3',
#  'audio\\Mad Heads - Новий рік! (мультиплікаційний кліп).mp3',
#  'audio\\Blooms Corda - Чувак, що продав світ (Man Who Sold the World) - Bowie Night 2024.mp3',
#  'audio\\Zoloto Reinu.mp3',
#  'audio\\blooms corda // mozhe.mp3',
#  'audio\\Lyst Do Kathrine.mp3',
#  'audio\\Твои глаза.mp3',
#  'audio\\Сива борода.mp3',
#  'audio\\Tvaryna.mp3',
#  'audio\\Барон.mp3',
#  'audio\\У пошуках милої людини.mp3',
#  'audio\\Blooms Corda // Куди все пішло / Q-session #1.mp3',
#  'audio\\Dyvo.mp3',
#  'audio\\Ницо Потворно — Недоречний.mp3',
#  'audio\\Нова радість стала  Піккардійська терція.mp3',
#  'audio\\Трикутний ключ.mp3',
#  'audio\\Pikkardiyska Tertsiya   Hej, sokoly!.mp3',
#  'audio\\Cyriyan.mp3',
#  'audio\\Kalush Orchestra - Вогонь горить.mp3',
#  'audio\\Фактично самі - Листи.mp3',
#  'audio\\Kalush Orchestra - Ти мене (LIVE).mp3',
#  'audio\\Фактично Самі - Обернися.mpg.mp3',
#  'audio\\Kalush Orchestra - Shtomber Womber (LIVE).mp3',
#  'audio\\Kalush Orchestra - CHANGES.mp3',
#  'audio\\Kalush Orchestra - Рута.mp3',
#  'audio\\Qarpa (Fucktychno Sami) - Любе лібідо (lyube libido).mp3',
#  'audio\\Kalush Orchestra & KOZAK SIROMAHA - Нумо Козаки.mp3',
#  'audio\\Пiккардiйська Терцiя - Старенький Трамвай.mp3',
#  'audio\\Гей, пливе кача.mp3',
#  'audio\\Піккардійська Терція - Сядеш у поїзд (онлайн-концерт 2020).mp3',
#  "audio\\ГІМН СВИНОГОР'Я (ІВАН ПАЛАМІТЕ) - НИЦО ПОТВОРНО.mp3",
#  'audio\\Ницо Потворно - Політика.mp3',
#  'audio\\Піккардійська Терція (Tercja Pikardyjska) - Pustelnik  (A capella).mp3',
#  'audio\\Слова.mp3',
#  'audio\\Юесей.mp3',
#  'audio\\Чемний панк.mp3',
#  'audio\\Піккардійська Терція - 06. Shizgara.mp3',
#  'audio\\Київ.mp3',
#  'audio\\Ницо Потворно — Да!.mp3',
#  'audio\\Тоталітарний геймовер.mp3',
#  'audio\\Маша Кондратенко - Я не сумую по тобі (skit).mp3',
#  'audio\\Олександр Пономарьов - Чомусь так гірко плакала вона [Official Video].mp3',
#  'audio\\Гімн України/ Anthem of Ukraine. Олександр Пономарьов/ Oleksandr Ponomaryov..mp3',
#  'audio\\Христина Соловій - Дівчинка «метелики в голові» (official audio).mp3',
#  'audio\\Вейкап.mp3',
#  'audio\\Напад на лігвище черепашок | Підлітки-мутанти черепашки-ніндзя (2014) | Український дубляж.mp3',
#  'audio\\Христина Соловій - Под облачком (official video).mp3',
#  'audio\\KAZKA — СВЯТА [OFFICIAL VIDEO].mp3',
#  'audio\\Христина Соловій - Тече вода каламутна (official audio).mp3',
#  'audio\\Христина Соловій - Горе долом (Наживо у Львівській Опері 2017).mp3',
#  'audio\\Христина Соловій - Хвиля (official audio).mp3',
#  'audio\\Коля не знау.mp3',
#  'audio\\Христина Соловій - В темну нічку (official audio).mp3',
#  'audio\\Перед війною.mp3',
#  'audio\\Студентські вихідні.mp3',
#  'audio\\Серцевий Напад - Punk Girl (2009).mp3',
#  'audio\\Олександр Пономарьов - Я ніколи нікому тебе не віддам [Official Video].mp3',
#  'audio\\Рубці.mp3',
#  'audio\\Тарас Чубай - Я так довго мовчав.mp3',
#  'audio\\Тарас Чубай "Птахи" - Скрябін. Концерт пам\'яті.mp3',
#  'audio\\Капелюх.mp3',
#  'audio\\Не Плачте, Не Журіться.mp3',
#  'audio\\Над морем.mp3',
#  'audio\\PROBASS ∆ HARDI - КОЗАКИ ЙДУТЬ (feat. ANNA BULAT).mp3',
#  'audio\\PROBASS ∆ HARDI - MANTRA.mp3',
#  'audio\\Гей Гу, Гей Га.mp3',
#  'audio\\PROBASS ∆ HARDI - DESERT ROSE (Official Audio).mp3',
#  'audio\\Червона Рута.mp3',
#  'audio\\Христина Соловій - Fortepiano (official video).mp3',
#  'audio\\Встигнути до 30 (From “Встигнути до 30”).mp3',
#  'audio\\Tember Blanche - Ти живий.mp3',
#  'audio\\Tember Blanche - Пролог.mp3',
#  'audio\\Димна Суміш - Кращий друг самурая.mp3',
#  'audio\\Шукай.mp3',
#  'audio\\Молоток.mp3',
#  'audio\\Орест Лютий - Путін, отьєбісь (архів 2014).mp3',
#  'audio\\Герой.mp3',
#  'audio\\Повмирай зi мною.mp3',
#  'audio\\Орест Лютий - Гендерні війни.mp3',
#  'audio\\Димна Сумiш - Протидiя.mp3',
#  'audio\\Воплі Відоплясова - Пісенька (Караоке версія).mp3',
#  'audio\\Орест Лютий - Я є народ.mp3',
#  'audio\\Орест Лютий - Котлети з онука (архів).mp3',
#  'audio\\Орест Лютий - "Народная Шахтьорская".mp3',
#  'audio\\Klavdia Petrivna — Я щаслива (Лікарі кажуть).mp3',
#  'audio\\Klavdia Petrivna — Імператори.mp3',
#  'audio\\Klavdia Petrivna — Театр.mp3',
#  'audio\\Klavdia Petrivna — Барон.mp3',
#  'audio\\Klavdia Petrivna — Сонце, жара.mp3',
#  'audio\\Орест Лютий - Цвіте бавовна.mp3',
#  'audio\\Klavdia Petrivna, Amphiphil — Я тобі брехала (remix).mp3',
#  'audio\\ОРЕСТ ЛЮТИЙ - РОСІЯН В ДОНБАСЄ НЄТ.mp3',
#  'audio\\Tember Blanche - Хованки.mp3',
#  "audio\\Tember Blanche - О дев'ятій (лірик відео).mp3",
#  'audio\\Tember Blanche - Ненародженим.mp3',
#  'audio\\Я піду в далекі гори.mp3',
#  'audio\\ранок (Bonus).mp3',
#  'audio\\Козаки йдуть (feat. Anna Bulat) - Extended mix.mp3',
#  'audio\\5Хвилин.mp3',
#  "audio\\БЕЗ ОБМЕЖЕНЬ - Буду з тобою (прем'єра кліпу 2018).mp3",
#  'audio\\Бумбокс - Звезды не ездят в метро..mp3',
#  'audio\\БЕЗ ОБМЕЖЕНЬ – Героям (UA).mp3',
#  "audio\\БЕЗ ОБМЕЖЕНЬ – Без неї ніяк (Прем'єра 2016)  Український хіт 2016.mp3",
#  'audio\\Чому.mp3',
#  'audio\\Так боляче!.mp3',
#  'audio\\Бумбокс - Пєпєл, OST "Пепел" (Full HD).mp3',
#  'audio\\Скажи щось погане - Бар.mp3',
#  'audio\\Бумбокс & O.Torvald - Вечiр в Рiо.mp3',
#  'audio\\Холодне Сонце - 07. Безкрилий ангел.mp3',
#  'audio\\Холодне Сонце - 09. Там, де я.mp3',
#  'audio\\Гурт «O» — Добре (Stage 13).mp3',
#  'audio\\Für Sie.mp3',
#  'audio\\Холодне Сонце - Коли вдома усі на Різдво (Official Video).mp3',
#  'audio\\Холодне Сонце - Чи без Тебе є Рай? (Lyric Video).mp3',
#  'audio\\гурт [О] — Хто Я?.mp3',
#  'audio\\А ти спитала мені як?.mp3',
#  'audio\\гурт [O] - Чим Я Не Така? (Official Music Video).mp3',
#  'audio\\Зіронька - Олександр Пономарьов.mp3',
#  'audio\\Олександр Пономарьов,Михайло Хома,Тарас Тополя,ALEKSEEV-Миліша#ponomarov#dzidzio #антитіла#alekseev.mp3',
#  'audio\\Скрябін — Люди як кораблі [Official Video].mp3',
#  'audio\\Александр Пономарёв. Святая Анна..mp3',
#  'audio\\Олександр Пономарьов - Варто чи ні [Official Video].mp3',
#  "audio\\БЕЗ ОБМЕЖЕНЬ - Хочеш [Прем'єра кліпу 2018].mp3",
#  'audio\\"ЗОЛОТА ТРАВА" - Тарас Чубай та "ПЛАЧ ЄРЕМІЇ".mp3',
#  'audio\\PROBASS ∆ HARDI - BMW vs AMG | Official Audio | 2020.mp3',
#  'audio\\БЕЗ ОБМЕЖЕНЬ - МОЯ КРАЇНА [OFFICIAL VIDEO].mp3',
#  'audio\\PROBASS ∆ HARDI & FOLK5 PROJECT - QAMIN ZANA (Official Audio).mp3',
#  'audio\\Свідомий вибір.mp3',
#  'audio\\PROBASS ∆ HARDI & Mordax Bastards - Paradise (Official Video).mp3',
#  'audio\\PROBASS ∆ HARDI  - Ой по горі роман цвіте (feat.  Юрій Йосифович).mp3',
#  'audio\\в чому сенс?.mp3',
#  'audio\\підліткове.mp3',
#  'audio\\Без Обмежень Without Limits–Я дихаю тобою.mp3',
#  'audio\\Плач Єремії - Єхидна.mp3',
#  'audio\\Плач Єремії - Хата моя.mp3',
#  'audio\\Плач Єремії - Відшукування причетного.mp3',
#  'audio\\Плач Єремії   "Сумна жінка".mp3',
#  "audio\\Плaч Єpeмiї - Клітка///Jeremiah's Lamеnt - cage.mp3",
#  'audio\\Тарас Чубай  СИПЛЕ СНІГ.mp3',
#  'audio\\БЕЗ ОБМЕЖЕНЬ - Не знаю як.mp3',
#  'audio\\Пісня буде поміж нас.mp3',
#  'audio\\Мила моя.mp3',
#  'audio\\"Ти Бачиш..." - сл. Григорій Чубай, муз. Т. Чубай.mp3',
#  'audio\\Повіяв Вітер Степовий.mp3',
#  'audio\\БЕЗ ОБМЕЖЕНЬ - До небес.mp3',
#  'audio\\Плач Єремії (Тарас Чубай) — Пластунка N.mp3',
#  'audio\\Запам’ятаю.mp3',
#  'audio\\БЕЗ ОБМЕЖЕНЬ - МАМИНІ СЛОВА (live @ Палац Спорту, 18.12.2018).mp3',
#  'audio\\Плач Єремії - Запроси мене у сни.mp3',
#  'audio\\KAZKA - Plakala (R3HAB Remix).mp3',
#  'audio\\"КОМУ ВНИЗ": "Неба Зорі".mp3',
#  'audio\\THE HARDKISS - In Love (official video).mp3',
#  'audio\\Колись.mp3',
#  'audio\\Рай.mp3',
#  "audio\\Краков'як рок.mp3",
#  'audio\\THE HARDKISS - Кораблі (official video).mp3',
#  'audio\\Королева.mp3',
#  'audio\\alyona alyona – Відчиняй.mp3',
#  'audio\\Море.mp3',
#  'audio\\Мамай.mp3',
#  'audio\\Білі плями.mp3',
#  'audio\\Один в каное - Ікони (Шістдесятникам).mp3',
#  'audio\\Велика сила.mp3',
#  'audio\\Воплі Відоплясова - Були Деньки [Official Video].mp3',
#  'audio\\Галина.mp3',
#  'audio\\Машина.mp3',
#  'audio\\Антитіла - Їдем Їдем.mp3',
#  'audio\\Воплі Відоплясова  ОЛЯ.mp3',
#  'audio\\TVORCHI - Мова Тіла (Official Video).mp3',
#  'audio\\Боги.mp3',
#  'audio\\Гоп-ця.mp3',
#  'audio\\Вопли Видоплясова (ВВ) - Обернись.mp3',
#  'audio\\Тартак — Я Не Хочу.mp3',
#  'audio\\Тартак — 100%-ий плагіат.mp3',
#  'audio\\Океан Ельзи - Кішка | Kishka (official video).mp3',
#  'audio\\Розмова з Махатмою.mp3',
#  'audio\\Бумбокс - Eva (Full HD).mp3',
#  'audio\\Ну, пострибай.mp3',
#  'audio\\Воплі Відоплясова - 01. Кармен (live).mp3',
#  'audio\\Галелуя.mp3',
#  'audio\\Intro Road.mp3',
#  'audio\\Сьогодні.mp3',
#  "audio\\Воплі Відоплясова  Зв'язок 1989.mp3",
#  'audio\\Шалена зірка.mp3',
#  'audio\\Воплі Відоплясова - Катерино.mp3',
#  'audio\\Одна.mp3',
#  'audio\\Або-або.mp3',
#  'audio\\Дитинство  - Воплі Відоплясова. 30 років.mp3',
#  'audio\\Воплі Відоплясова - Колискова.mp3',
#  'audio\\Воплі Відоплясова - Чіо Чіо Сан.mp3',
#  'audio\\Vivienne Mort — Вечір.mp3',
#  'audio\\Vivienne Mort — Сліди маленьких рук [офіційний відеокліп].mp3',
#  'audio\\Вогнi.mp3',
#  'audio\\alyona alyona – Рибки.mp3',
#  'audio\\Vivienne Mort — Той, хто рятує імена [Rosa, 2016].mp3',
#  'audio\\THE HARDKISS - TONY, TALK! (official video).mp3',
#  'audio\\THE HARDKISS - Жива (official video).mp3',
#  'audio\\Намалюй.mp3',
#  "audio\\Go_A - Добрим людям на здоров'я (Lyric Video).mp3",
#  'audio\\Go-A - Іди на звук [Follow the Tune] (audio).mp3',
#  'audio\\Мало мені.mp3',
#  'audio\\Go_A - Krip (Official Music Video).mp3',
#  'audio\\Vivienne Mort — Іній [single, 2017].mp3',
#  'audio\\Намалюй (Акустична Версія).mp3',
#  'audio\\Моя дівчина.mp3',
#  'audio\\Тартак — Я Не Знаю.mp3',
#  "audio\\Vivienne Mort — Пам'ятаєш [Unofficial Music Video].mp3",
#  'audio\\alyona alyona & KOLA - Небо хилиться.mp3',
#  'audio\\Go_A - Rusalochki.mp3',
#  "audio\\alyona alyona - Не втратимо зв'язок.mp3",
#  'audio\\Сонце.mp3',
#  'audio\\alyona alyona - Залишаю свій дім.mp3',
#  'audio\\Воплі Відоплясова - Полонина [Official Video].mp3',
#  'audio\\Воплі Відоплясова - Ладо.mp3',
#  'audio\\alyona alyona - Булiнг.mp3',
#  'audio\\Бумбокс & The Gitas - Тримай мене.mp3',
#  'audio\\Воплі Відоплясова - Щедрик.mp3',
#  'audio\\Тартак — Нашеліто.mp3',
#  'audio\\THE HARDKISS - Прiрва..mp3',
#  'audio\\Go_A - ШУМ (Official Video).mp3',
#  'audio\\Vivienne Mort - Лети.mp3',
#  'audio\\Бумбокс - Наодинцi (Full HD).mp3',
#  'audio\\alyona alyona - Сніг розталий.mp3',
#  'audio\\Янанебібув.mp3',
#  'audio\\Бумбокс - Вахтерам | Official Video.mp3',
#  'audio\\Lama - Знаєш як Болить.mp3',
#  'audio\\Vivienne Mort - День, коли святі  [театр PipinO, 2013].mp3',
#  'audio\\Вічна, жива.mp3',
#  'audio\\alyona alyona - Тихо діти сплять.mp3',
#  'audio\\Океан Ельзи - Там, де нас нема | Tam de nas nema (official video).mp3',
#  'audio\\Рибка.mp3',
#  'audio\\Океан Ельзи - Відпусти | Vidpusty (official video).mp3',
#  'audio\\Антитіла - Вибирай / Official video.mp3',
#  'audio\\Жадан і Собаки, Мертвий півень – Переваги окупаційного режиму (Офіційне відео).mp3',
#  'audio\\Друга Ріка - Фурія.mp3',
#  "audio\\Один в каное - Пам'яті мало.mp3",
#  'audio\\KAZKA — КАРМА [OFFICIAL AUDIO].mp3',
#  'audio\\Гуцулка Ксеня.mp3',
#  'audio\\Вiддаю.mp3',
#  'audio\\KAZKA — МОВЧАТИ [OFFICIAL AUDIO].mp3',
#  'audio\\KAZKA — ЗАПАЛА [OFFICIAL AUDIO].mp3',
#  'audio\\Сам собі острів.mp3',
#  "audio\\KAZKA - М'ята [Official Music Video] #SVIT.mp3",
#  'audio\\Друга Ріка — інша ріка.mp3',
#  'audio\\Один в каное - Про білизну.mp3',
#  'audio\\Шо ти зміг.mp3',
#  'audio\\Друга Ріка –\xa0Доки я не пішов.mp3',
#  'audio\\Один в каное - Осінь.mp3',
#  'audio\\Один в каное - От і все.mp3',
#  'audio\\Друга Ріка - Там де ти.mp3',
#  'audio\\П’ятниця.mp3',
#  'audio\\Ed Sheeran – 2step ft Antytila [Official Video].mp3',
#  'audio\\Один в каное - Румба.mp3',
#  'audio\\THE HARDKISS - Журавлi (official video).mp3',
#  'audio\\THE HARDKISS - Stones (official video).mp3',
#  'audio\\Cash-бабулес.mp3',
#  'audio\\Антитіла - Я не забуду першу ніч / SONG.mp3',
#  'audio\\Друга Ріка – ТИ Є Я.mp3',
#  'audio\\KAZKA — САМА [OFFICIAL AUDIO].mp3',
#  'audio\\Vivienne Mort - Маріула [Готика, 2014].mp3',
#  'audio\\Зцапала-злапала.mp3',
#  'audio\\KAZKA — ДИВА [OFFICIAL VIDEO].mp3',
#  'audio\\Друга Ріка - Кінець світу.mp3',
#  'audio\\Антитіла - Люди, як кораблі / Official video.mp3',
#  'audio\\Попс.mp3',
#  'audio\\Зима.mp3',
#  'audio\\Знаєш.mp3',
#  'audio\\Vivienne Mort - Temno [Filin, 2015].mp3',
#  'audio\\Один в каное - Дерево.mp3',
#  'audio\\Друга Ріка - Відчиняй.mp3',
#  'audio\\Новий день.mp3',
#  'audio\\Динама.mp3',
#  'audio\\Воплі Відоплясова - Веселковий твiст (1990 рік).mp3',
#  'audio\\Vivienne Mort -  Грушечка [Filin, 2015].mp3',
#  'audio\\Гей, налягай.mp3',
#  'audio\\Олрай.mp3',
#  'audio\\Апокаліпсис.mp3',
#  'audio\\Антитіла - Тебе моя невеста.mp3',
#  'audio\\Мусса.mp3',
#  'audio\\TVORCHI - Bonfire (Official Video) (EUROVISION 2020).mp3',
#  'audio\\Викину 2.mp3',
#  'audio\\Друга Ріка — Kosmozoo (інша ріка).mp3',
#  'audio\\KAZKA — ZEMNA [OFFICIAL AUDIO] #NIRVANA.mp3',
#  'audio\\Vivienne Mort - перейди, місяцю! [театр PipinO, 2013].mp3',
#  'audio\\Один в каное - Мамма.mp3',
#  'audio\\Океан Ельзи - Квітка | Kvitka  (official video).mp3',
#  'audio\\Один в каное - Шахи.mp3',
#  'audio\\Бета-каротин.mp3',
#  'audio\\Танго.mp3',
#  'audio\\KAZKA — NOBODY LIKE YOU [OFFICIAL AUDIO].mp3',
#  'audio\\TVORCHI - Heart Of Steel (LIVE) | Ukraine 🇺🇦 | Grand Final | Eurovision 2023.mp3',
#  'audio\\O.TORVALD - Киев днём и ночью [Audio].mp3',
#  'audio\\KAZKA — ТВОЄЇ КРОВІ [OFFICIAL AUDIO] #NIRVANA.mp3',
#  'audio\\Это все.mp3']

# %% [markdown]
# It seems like we have to cases:
# 1. It is literaly the same song but with slightly different title name in the LastFM platform

# %%
filtered_songs_df[filtered_songs_df["audio_path"] == 'audio\\Ало-але.mp3']
# Out:
#                  title          artist         audio_path yt_title  \
# 752            Ало-але  Крихітка Цахес  audio\Ало-але.mp3  Ало-але
# 805            Ало але  Крихітка Цахес  audio\Ало-але.mp3  Ало-але
# 812          Алло, але  Крихітка Цахес  audio\Ало-але.mp3  Ало-але
# 813  Твої ало, мої але  Крихітка Цахес  audio\Ало-але.mp3  Ало-але
# 818           Ало, але  Крихітка Цахес  audio\Ало-але.mp3  Ало-але
#
#                                       yt_url  yt_duration  yt_views
# 752  https://youtube.com/watch?v=xH6cxIXtGWI        222.0  172200.0
# 805  https://youtube.com/watch?v=xH6cxIXtGWI        222.0  172201.0
# 812  https://youtube.com/watch?v=xH6cxIXtGWI        222.0  172201.0
# 813  https://youtube.com/watch?v=xH6cxIXtGWI        222.0  172201.0
# 818  https://youtube.com/watch?v=xH6cxIXtGWI        222.0  172201.0

# %% [markdown]
# 2. Those are different songs, but the script failed to search the relevant YT audio (in some cases it doesn't even exist on YT)

# %%
filtered_songs_df[filtered_songs_df["audio_path"] == "audio\Крихітка Цахес - На Першому Місці.mp3"]
# Out:
#                     title          artist  \
# 750      На першому місці  Крихітка Цахес
# 771   Ти на першому місці  Крихітка Цахес
# 777     На першому  місці  Крихітка Цахес
# 782      На першому мiсцi  Крихітка Цахес
# 800  Ty na pershomu misci  Крихітка Цахес
# 801      На першому місті  Крихітка Цахес
# 814     На першому  місті  Крихітка Цахес
#
#                                       audio_path  \
# 750  audio\Крихітка Цахес - На Першому Місці.mp3
# 771  audio\Крихітка Цахес - На Першому Місці.mp3
# 777  audio\Крихітка Цахес - На Першому Місці.mp3
# 782  audio\Крихітка Цахес - На Першому Місці.mp3
# 800  audio\Крихітка Цахес - На Першому Місці.mp3
# 801  audio\Крихітка Цахес - На Першому Місці.mp3
# 814  audio\Крихітка Цахес - На Першому Місці.mp3
#
#                               yt_title  \
# 750  Крихітка Цахес - На Першому Місці
# 771  Крихітка Цахес - На Першому Місці
# 777  Крихітка Цахес - На Першому Місці
# 782  Крихітка Цахес - На Першому Місці
# 800  Крихітка Цахес - На Першому Місці
# 801  Крихітка Цахес - На Першому Місці
# 814  Крихітка Цахес - На Першому Місці
#
#                                       yt_url  yt_duration  yt_views
# 750  https://youtube.com/watch?v=RT6BXmAArYc        212.0  102050.0
# 771  https://youtube.com/watch?v=RT6BXmAArYc        212.0  102050.0
# 777  https://youtube.com/watch?v=RT6BXmAArYc        212.0  102050.0
# 782  https://youtube.com/watch?v=RT6BXmAArYc        212.0  102050.0
# 800  https://youtube.com/watch?v=RT6BXmAArYc        212.0  102051.0
# 801  https://youtube.com/watch?v=RT6BXmAArYc        212.0  102051.0
# 814  https://youtube.com/watch?v=RT6BXmAArYc        212.0  102051.0

# %% [markdown]
# We need to perform two further postprocessing steps:
# 1. Normalize artist and titles and filter duplicates
# 2. Prepare a column which will indicate the need for re-downloading the audio (or setting None if it doesn't exist on YT)

# %%
non_unique_paths = filtered_songs_df.groupby("title").filter(lambda x: x["artist"].nunique() > 1)["audio_path"].value_counts()
non_unique_paths = non_unique_paths[non_unique_paths > 1].index.tolist()
non_unique_paths
# Out:
# ['audio\\Воплі Відоплясова - Були на селі.mp3',
#  'audio\\Воплі Відоплясова - ВЕСНА.mp3',
#  'audio\\Їхали козаки.mp3',
#  'audio\\Там, Під Львівським Замком.mp3',
#  'audio\\Intro.mp3',
#  'audio\\Пачка цигарок.mp3',
#  'audio\\Жадан і Собаки feat. Gogol Bordello – 5-а авеню (Офіційне відео).mp3',
#  'audio\\Воплі Відоплясова - Сонячні дні [Official Video].mp3',
#  'audio\\Воплі Відоплясова - Зоряна осінь.mp3',
#  'audio\\Кедь Ми Пришла Карта.mp3',
#  'audio\\Воплі Відоплясова - Танцi.mp3',
#  'audio\\Я підійду.mp3',
#  'audio\\Тартак feat. Катя Chilly — Понад Хмарами....mp3',
#  'audio\\Трава.mp3',
#  'audio\\Глибина.mp3',
#  'audio\\Плач Єремії - Ти втретє цього літа зацвітеш.mp3',
#  'audio\\Буде Нам З Тобою Що Згадати....mp3',
#  'audio\\Олександр Пономарьов "Сам собі країна" - Скрябін. Концерт пам\'яті.mp3',
#  'audio\\Жадан і Собаки, Христина Соловій – Серце (Офіційне відео).mp3',
#  'audio\\Ми - хлопці з Бандерштадту.mp3',
#  'audio\\Вона.mp3',
#  'audio\\Я твоє крило.mp3',
#  'audio\\Жадан і Собаки – Автозак (Офіційне відео).mp3',
#  'audio\\Жадан і Собаки – Мальви (Офіційне відео).mp3',
#  'audio\\Жадан i Собаки – Троєщина (live @On-Air).mp3',
#  'audio\\Жадан і Собаки – Ріка (Офіційне відео).mp3',
#  'audio\\Жадан і Собаки – Мадонна (Lyric Video).mp3',
#  'audio\\Жадан і Собаки – Бухло (Офіційне відео).mp3',
#  'audio\\Жадан і Собаки – Кобзон (Офіційне відео).mp3',
#  'audio\\Жадан і Собаки – Тьолка барабанщика (Офіційне відео).mp3',
#  'audio\\Натаха.mp3',
#  'audio\\Жадан і Собаки feat. Брати Гадюкіни – Наркомани на городі (Жадан і Собаки cover).mp3',
#  'audio\\Ты ушёл.mp3',
#  'audio\\Олрай.mp3',
#  'audio\\Відрада.mp3',
#  'audio\\Воплі Відоплясова - Світ.mp3',
#  'audio\\Або-або.mp3',
#  'audio\\Воплі Відоплясова - Катерино.mp3',
#  'audio\\Шалена зірка.mp3',
#  'audio\\Підманула.mp3',
#  "audio\\Воплі Відоплясова  Зв'язок 1989.mp3",
#  'audio\\Галелуя.mp3',
#  'audio\\Воплі Відоплясова - 01. Кармен (live).mp3',
#  'audio\\Розмова з Махатмою.mp3',
#  'audio\\Колискова.mp3',
#  'audio\\Танго.mp3',
#  'audio\\Гей, любо!.mp3',
#  'audio\\Апокаліпсис.mp3',
#  'audio\\Гей, налягай.mp3',
#  'audio\\Динама.mp3',
#  'audio\\Воплі Відоплясова - Веселковий твiст (1990 рік).mp3',
#  'audio\\Жадан і Собаки –\xa0Вафлі Артек (Офіційне відео).mp3',
#  'audio\\Мусса.mp3',
#  'audio\\Попс.mp3',
#  'audio\\Жадан і Собаки – Кокаїн (Lyric Video).mp3',
#  'audio\\Жадан і Собаки – Рогань (Офіційне відео).mp3',
#  'audio\\Жадан і Собаки – Марат  (Live Drum Session).mp3',
#  'audio\\Повіяв Вітер Степовий.mp3',
#  'audio\\Чому.mp3',
#  'audio\\гурт [О] — Хто Я?.mp3',
#  'audio\\Плач Єремії - Хата моя.mp3',
#  'audio\\Лента За Лентою.mp3',
#  'audio\\Водограй.mp3',
#  'audio\\Тарас Чубай "Миколай Бородатий" (фрагмент фільму "На Різдво до Львівського").mp3',
#  'audio\\Чубай Тарас - Із Янголом на Плечі     Chubai Taras - Angel on my Shoulder.mp3',
#  'audio\\Пісня буде поміж нас.mp3',
#  'audio\\"Ти Бачиш..." - сл. Григорій Чубай, муз. Т. Чубай.mp3',
#  'audio\\Плач Єремії (Тарас Чубай) — Пластунка N.mp3',
#  'audio\\Вопли Видоплясова (ВВ) - Обернись.mp3',
#  'audio\\Нестримна течія.mp3',
#  'audio\\"ЗОЛОТА ТРАВА" - Тарас Чубай та "ПЛАЧ ЄРЕМІЇ".mp3',
#  'audio\\Ми Йдем Вперед.mp3',
#  "audio\\Холодне Сонце - Твоє ім'я (HD).mp3",
#  'audio\\Досить!.mp3',
#  'audio\\Скрябін — Люди як кораблі [Official Video].mp3',
#  'audio\\Пілігрим.mp3',
#  'audio\\Ницо Потворно - Хто я.mp3',
#  'audio\\Kalush Orchestra - Stefania (Official Video Eurovision 2022).mp3',
#  'audio\\Димна Сумiш - Зламанi.mp3',
#  'audio\\Шукай.mp3',
#  'audio\\Ближче.mp3',
#  'audio\\Забудь мене.mp3',
#  'audio\\Радіопромінь.mp3',
#  'audio\\Outro.mp3',
#  'audio\\Жадан і Собаки – Виживи feat. Ірена Карпа (Офіційне відео).mp3',
#  'audio\\Вова.mp3',
#  'audio\\Буратіно.mp3',
#  'audio\\Жадан і Собаки – Дивні люди (Офіційне відео).mp3',
#  'audio\\Жадан і Собаки – Метро (Аудіо).mp3',
#  'audio\\KALUSH - Зорі.mp3',
#  'audio\\Віскі.mp3',
#  'audio\\Перекличка.mp3',
#  'audio\\Вона сама сюди прийшла.mp3',
#  'audio\\Закладчик.mp3',
#  'audio\\Печінка.mp3',
#  'audio\\Забухав.mp3',
#  'audio\\Антидепресанти.mp3',
#  'audio\\Серце.mp3',
#  'audio\\СТРУКТУРА ЩАСТЯ - Запам‘ятай мої рядки (feat. Sad Novelist).mp3',
#  'audio\\Трохи про нас.mp3',
#  "audio\\Пароль до ї' губ.mp3",
#  'audio\\Дитинство  - Воплі Відоплясова. 30 років.mp3',
#  'audio\\Жадан і Собаки – Діти (Повна версія) | Анімаційне відео.mp3',
#  'audio\\Гоп-ця.mp3',
#  'audio\\Воплі Відоплясова  ОЛЯ.mp3',
#  'audio\\Воплі Відоплясова - Горіла Сосна.mp3',
#  'audio\\Воплі Відоплясова - Полонина [Official Video].mp3',
#  'audio\\Воплі Відоплясова — Музіка [Official Video].mp3',
#  'audio\\Воплі Відоплясова - Любов [Official Video].mp3',
#  'audio\\Воплі Відоплясова - Ладо.mp3',
#  'audio\\Воплі Відоплясова - Країна Мрій.mp3',
#  'audio\\Воплi Вiдоплясова - Юра.mp3',
#  'audio\\Воплі Відоплясова - День Народження.mp3',
#  'audio\\◾Плач Єремії ◾ Вона ◾.mp3',
#  'audio\\Христина Соловій - Тримай (official video).mp3',
#  'audio\\Новий день.mp3',
#  'audio\\Зима.mp3',
#  'audio\\Одна.mp3',
#  'audio\\Королева.mp3',
#  'audio\\Сонце.mp3',
#  'audio\\Антитіла - Люди, як кораблі / Official video.mp3',
#  'audio\\Стіна.mp3',
#  'audio\\Воплі Відоплясова - Колискова.mp3',
#  'audio\\Пiккардiйська Терцiя - Старенький Трамвай.mp3',
#  'audio\\Боги.mp3',
#  'audio\\Галю приходь - Воплі Відоплясова. 30 років.mp3',
#  'audio\\Гармонія.mp3',
#  "audio\\Краков'як рок.mp3",
#  'audio\\Воплі Відоплясова - Таємнi сфери (офіційне відео).mp3',
#  'audio\\Є-є.mp3',
#  'audio\\Рай.mp3',
#  'audio\\Колись.mp3',
#  'audio\\Машина.mp3',
#  'audio\\Море.mp3',
#  'audio\\Мамай.mp3',
#  'audio\\Білі плями.mp3',
#  'audio\\Велика сила.mp3',
#  'audio\\Воплі Відоплясова - Були Деньки [Official Video].mp3',
#  'audio\\Галина.mp3']

# %%
antitila_df = filtered_songs_df[filtered_songs_df["audio_path"] == 'audio\\Я підійду.mp3']
antitila_df
# Out:
#           title             artist           audio_path   yt_title  \
# 627   Я підійду  Воплі Відоплясова  audio\Я підійду.mp3  Я підійду
# 643   Я пiдiйду  Воплі Відоплясова  audio\Я підійду.mp3  Я підійду
# 1380  Я пiдiйду  Воплi Вiдоплясова  audio\Я підійду.mp3  Я підійду
# 1385  Я підійду  Воплi Вiдоплясова  audio\Я підійду.mp3  Я підійду
#
#                                        yt_url  yt_duration  yt_views
# 627   https://youtube.com/watch?v=eBTkMoyZgp0        137.0   31225.0
# 643   https://youtube.com/watch?v=eBTkMoyZgp0        137.0   31225.0
# 1380  https://youtube.com/watch?v=eBTkMoyZgp0        137.0   31226.0
# 1385  https://youtube.com/watch?v=eBTkMoyZgp0        137.0   31226.0

# %%
antitila_df["artist"].value_counts()
# Out:
# Воплі Відоплясова    2
# Воплi Вiдоплясова    2
# Name: artist, dtype: int64

# %%
antitila_df["title"].value_counts()
# Out:
# Я підійду    2
# Я пiдiйду    2
# Name: title, dtype: int64
